# %%
import pandas as pd

# %%
train_df = pd.read_csv("/Users/hesu/Documents/KT/riiid/train.csv")

# %%
train_df.head(10)
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
# 5       5     157063      115         156                0                  5
# 6       6     176092      115          51                0                  6
# 7       7     194190      115          50                0                  7
# 8       8     212463      115        7896                0                  8
# 9       9     230983      115        7863                0                  9
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# ...

# %%
test_df = pd.read_csv("/Users/hesu/Documents/KT/riiid/example_test.csv")

# %%
test_df.head(10)
# Out:
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
# 5       5          0  18020362258  1364159702       12023                0
# 6       6          0   2325432079  1521618396         574                0
# 7       7          0  39456940781  1317245193       12043                0
# 8       8          0   3460555189  1700555100        7910                0
# 9       9          0   2214770464   998511398        7908                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# ...

# %%
train_user1 = train_df.loc[train_df['user_id'] == -1]

# %%
train_user1
# Out:
# Empty DataFrame
# Columns: [row_id, timestamp, user_id, content_id, content_type_id, task_container_id, user_answer, answered_correctly, prior_question_elapsed_time, prior_question_had_explanation]
# Index: []

# %%
train_user2 = train_df.loc[train_df['user_id'] == 115]

# %%
train_user2
# Out:
#     row_id  timestamp  user_id  content_id  content_type_id  \
# 0        0          0      115        5692                0
# 1        1      56943      115        5716                0
# 2        2     118363      115         128                0
# 3        3     131167      115        7860                0
# 4        4     137965      115        7922                0
# 5        5     157063      115         156                0
# 6        6     176092      115          51                0
# 7        7     194190      115          50                0
# 8        8     212463      115        7896                0
# 9        9     230983      115        7863                0
# 10      10     255381      115         152                0
# 11      11     280033      115         104                0
# 12      12     302994      115         108                0
# 13      13     328686      115        7900                0
# 14      14     352686      115        7901                0
# ...

# %%
train_user1.empty
# Out:
# True

# %%
train_user2.empty
# Out:
# False

# %%
import numpy as np

# %%
train_user3 = train_df.loc[train_df['timestamp'] == np.nan]

# %%
train_user3
# Out:
# Empty DataFrame
# Columns: [row_id, timestamp, user_id, content_id, content_type_id, task_container_id, user_answer, answered_correctly, prior_question_elapsed_time, prior_question_had_explanation]
# Index: []

# %%
test_df.head(10)
# Out:
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
# 5       5          0  18020362258  1364159702       12023                0
# 6       6          0   2325432079  1521618396         574                0
# 7       7          0  39456940781  1317245193       12043                0
# 8       8          0   3460555189  1700555100        7910                0
# 9       9          0   2214770464   998511398        7908                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# ...

# %%
tail_train = train_df[-10000:]

# %%
tail_train['content_type_id'].value_counts()
# Out:
# 0    9830
# 1     170
# Name: content_type_id, dtype: int64

# %%
tail_train
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 101220332  101220332  254558034  2147192453        6765                0
# 101220333  101220333  254788335  2147192453        8016                0
# 101220334  101220334  254788335  2147192453        8017                0
# 101220335  101220335  254788335  2147192453        8015                0
# 101220336  101220336  254788335  2147192453        8014                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  answered_correctly  \
# ...

# %%
tail_test = tail_train[tail_train['content_type_id']==0]

# %%
tail_test
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 101220332  101220332  254558034  2147192453        6765                0
# 101220333  101220333  254788335  2147192453        8016                0
# 101220334  101220334  254788335  2147192453        8017                0
# 101220335  101220335  254788335  2147192453        8015                0
# 101220336  101220336  254788335  2147192453        8014                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  answered_correctly  \
# ...

# %%
tail_test['answered_correctly'] = 1
# Out:
# /anaconda3/envs/torch1.4/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tail_test
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 101220332  101220332  254558034  2147192453        6765                0
# 101220333  101220333  254788335  2147192453        8016                0
# 101220334  101220334  254788335  2147192453        8017                0
# 101220335  101220335  254788335  2147192453        8015                0
# 101220336  101220336  254788335  2147192453        8014                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  answered_correctly  \
# ...

# %%
tail_train = tail_train.drop( columns=['answered_correctly'])

# %%
tail_train
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 101220332  101220332  254558034  2147192453        6765                0
# 101220333  101220333  254788335  2147192453        8016                0
# 101220334  101220334  254788335  2147192453        8017                0
# 101220335  101220335  254788335  2147192453        8015                0
# 101220336  101220336  254788335  2147192453        8014                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  prior_question_elapsed_time  \
# ...

# %%
tail_train.loc[:,['row_id','answered_correctly']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-1fdb831d6d5d> in <module>
# ----> 1 tail_train.loc[:,['row_id','answered_correctly']]
#
# /anaconda3/envs/torch1.4/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /anaconda3/envs/torch1.4/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# ...

# %%
tail_test
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 101220332  101220332  254558034  2147192453        6765                0
# 101220333  101220333  254788335  2147192453        8016                0
# 101220334  101220334  254788335  2147192453        8017                0
# 101220335  101220335  254788335  2147192453        8015                0
# 101220336  101220336  254788335  2147192453        8014                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  answered_correctly  \
# ...

# %%
sub = tail_test.loc[tail_test['content_type_id']==0,['row_id','answered_correctly']]

# %%
sub
# Out:
#               row_id  answered_correctly
# 101220332  101220332                   1
# 101220333  101220333                   1
# 101220334  101220334                   1
# 101220335  101220335                   1
# 101220336  101220336                   1
# ...              ...                 ...
# 101230327  101230327                   1
# 101230328  101230328                   1
# 101230329  101230329                   1
# 101230330  101230330                   1
# 101230331  101230331                   1
#
# [9830 rows x 2 columns]

# %%
train_df.head(10)
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
# 5       5     157063      115         156                0                  5
# 6       6     176092      115          51                0                  6
# 7       7     194190      115          50                0                  7
# 8       8     212463      115        7896                0                  8
# 9       9     230983      115        7863                0                  9
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# ...

# %%
target = train_df[train_df['content_id']>13522]

# %%
target
# Out:
#               row_id    timestamp     user_id  content_id  content_type_id  \
# 117              117     10183847        5382       16736                1
# 212              212   1424348597        5382       30207                1
# 216              216   1425557777        5382       18545                1
# 302              302    406265768        8623       25843                1
# 323              323    577424049        8623       29544                1
# ...              ...          ...         ...         ...              ...
# 101229661  101229661  13024358864  2147470777       18186                1
# 101229843  101229843  13084778540  2147470777       20474                1
# 101230063  101230063    132157858  2147482216       14325                1
# 101230195  101230195   1073593458  2147482216       21887                1
# 101230220  101230220   1240470616  2147482216       27699                1
#
#            task_container_id  user_answer  answered_correctly  \
# ...

# %%
target_test = target.loc[:,['row_id','timestamp','user_id','content_type_id','content_id']]

# %%
target_test
# Out:
#               row_id    timestamp     user_id  content_type_id  content_id
# 117              117     10183847        5382                1       16736
# 212              212   1424348597        5382                1       30207
# 216              216   1425557777        5382                1       18545
# 302              302    406265768        8623                1       25843
# 323              323    577424049        8623                1       29544
# ...              ...          ...         ...              ...         ...
# 101229661  101229661  13024358864  2147470777                1       18186
# 101229843  101229843  13084778540  2147470777                1       20474
# 101230063  101230063    132157858  2147482216                1       14325
# 101230195  101230195   1073593458  2147482216                1       21887
# 101230220  101230220   1240470616  2147482216                1       27699
#
# [1191807 rows x 5 columns]
